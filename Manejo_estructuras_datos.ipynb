# %% [markdown]
# <center> <h1> Estructuras de datos en Python </h1>
#
# ![image](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTncB2fp8FCRjubfKXk8Hvl_NA8ycwu2BmHwQ&usqp=CAU)
#
# </center>
#
#
#
#
# Expositor: Katherine Morales
#
# - Linkedin [in/katherine-morales-7194a3108/](https://www.linkedin.com/in/katherine-morales-7194a3108/)

# %% [markdown]
# # String Data Type
#
# - Es una secuencia de caracteres
# - Para strings, + significa concatenar
# - Cuando un string cintiene números, este es todavía un string
# - Podemos convertir números que están en formato string a un número utilizando **int()**

# %%
str1 = "Hola"
str2 = ' mundo'

# %%
msj = str1 + str2
print(msj)
# Out:
# Hola mundo

# %%
str3 = '123'
x = str3 + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-2c2d46e20be7> in <module>()
#       1 str3 = '123'
# ----> 2 x = str3 + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
x = int(str3) + 1
print(x)
# Out:
# 124

# %% [markdown]
# ## Leer y transformar
#
# Cuando 'leemos' los datos puede suceder que se lean como strings (es lo que prefiere la máquina.

# %%
entrada = input('Ingrese un nombre ')
# Out:
# Ingrese un nombre Katherine

# %%
entrada
# Out:
# 'Katherine'

# %%
entrada.__class__
# Out:
# str

# %%
edad = input('Ingrese su edad: ')
# Out:
# Ingrese su edad: 27

# %%
edad
# Out:
# '27'

# %%
edad + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-aef667aea955> in <module>()
# ----> 1 edad + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Solución al problema
# Aqui

# %% [markdown]
# ## Buscando dentro de los strings
#
# - Utilizamos corchetes para acceder a un caracter  []
# - El índice debe ser entero
# - También puede ser una expresión calculable

# %%
nombre =

# %%
letra = nombre[]

# %%
print(letra)

# %%
indice = 
letra2 = nombre[]

# %% [markdown]
# - Len function

# %%
ejemplo = 'taller'

# %% [markdown]
# - Loops con strings
#
# Tarea:
# Usando **while** y una variable de iteración, con ayuda de len, se imprima en pantalla el índice y la letra correspondiente
#
# 0 t
#
# 1 a
#
# 2 l
#
# 3 l
#
# 4 e
#
# 5 r
#
#
#
# - La variiable de iteración itera a lo largo de la seguencia
# - Ejecuta el cuerpo, el bloque de código
# - La variable de iteración se mueve a lo largo de todos los valores en la secuencia

# %% [markdown]
# Tarea: contar el número de veces que una letra aparece en una frase

# %%
texto = 'Estamos aprendiendo las estructuras de datos que existen en python y como manejarlas '

# %% [markdown]
# ## Algunos métodos

# %%
ejemplo3 = 'Katherine Morales'

# %%
ejemplo3.lower()
# Out:
# 'katherine morales'

# %%
ejemplo3.upper()
# Out:
# 'KATHERINE MORALES'

# %%
type(ejemplo3)
# Out:
# str

# %%
dir(ejemplo3)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
ejemplo3.split()
# Out:
# ['Katherine', 'Morales']

# %%
ejemplo3.replace('Katherine', 'Tania')
# Out:
# 'Tania Morales'

# %%
ejemplo3.replace('s', 'z')
# Out:
# 'Katherine Moralez'

# %%
# find
# lstrip
# rstirp
# strip

# %%
# análisis sintáctico y extracción

# %% [markdown]
# ## Extras

# %%
ejemplo
# Out:
# 'taller'

# %%
'e' in ejemplo
# Out:
# True

# %%
'k' not in ejemplo
# Out:
# True

# %%
ejemplo > ejemplo2
# Out:
# False

# %% [markdown]
# - Análisis sintáctico y extracción
# - Strings y conjuntos de caracteres

# %% [markdown]
# # Listas
#
# Al igual que un string, una lista es una secuencia de valores. En una cadena, los valores son caracteres; en una lista, pueden ser de cualquier tipo. Los valores de una lista se denominan elementos o, a veces, ítems.

# %%
lista1 = [1, 2, 3, 5]

# %%
lista2 = ['Curso', 'Python', 'Estructuras', 'Datos']

# %%
lista3 = [1, [3,5], 3]

# %%
lista = []

# %%
for k in lista1:
  print(k)
# Out:
# 1
# 2
# 3
# 5

# %% [markdown]
# Tarea: Crear una lista de  5 nombres e imprimer el mensaje personalizado para cada uno de ellos de Feliz Navidad (Nombre)
#
# Feliz Navidad Pablo!
#
# Feliz Navidad Mariana!

# %%
# Code here
nombres = []

# %% [markdown]
# - Listas son mutables (podemos cambiar un elemento de una lista usando el operador index)
#
# - Strings son inmutables (no podemos cambiar el contenido de un string)

# %% [markdown]
# El tamaño de una lista - len()

# %% [markdown]
# Acceder a los elementos []

# %%
lista1
# Out:
# [1, 2, 3, 5]

# %%
type(lista1)
# Out:
# list

# %% [markdown]
# ### Métodos de una lista

# %%
dir(lista1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
lista1
# Out:
# [1, 2, 3, 5]

# %%
x = []
x = list()
x
# Out:
# []

# %%
x.append(4)
x
# Out:
# [4]

# %%
x.append(5)

# %%
x
# Out:
# [4, 5]

# %%
x.remove(4)

# %%
x
# Out:
# [5]

# %% [markdown]
# - Enlace strings con listas

# %%
texto
# Out:
# 'Estamos aprendiendo las estructuras de datos que existen en python y como manejarlas '

# %%
palabras = texto.split()
palabras
# Out:
# ['Estamos',
#  'aprendiendo',
#  'las',
#  'estructuras',
#  'de',
#  'datos',
#  'que',
#  'existen',
#  'en',
#  'python',
#  'y',
#  'como',
#  'manejarlas']

# %%
texto2 = 'Este es un ejemplo. Para separar. por puntos'
texto2.split('.')
# Out:
# ['Este es un ejemplo', ' Para separar', ' por puntos']

# %%
texto3 = 'micorreo@dominio'
texto3.split('@')
# Out:
# ['micorreo', 'dominio']

# %%
lista1 + lista2
# Out:
# [1, 2, 3, 5, 'Curso', 'Datos', 'Estructuras', 'Python']

# %%
lista2*3
# Out:
# ['Curso',
#  'Datos',
#  'Estructuras',
#  'Python',
#  'Curso',
#  'Datos',
#  'Estructuras',
#  'Python',
#  'Curso',
#  'Datos',
#  'Estructuras',
#  'Python']

# %% [markdown]
# # Dictionaries
#
# - Key
# - Value
#
# -

# %%
d1 = dict()
d1['clave1'] = 2
d1['clave2'] = 3
d1['clave3'] = 24
d1
# Out:
# {'clave1': 2, 'clave2': 3, 'clave3': 24}

# %%
d1['clave1']
# Out:
# 2

# %%
d1['clave1'] = 33
d1
# Out:
# {'clave1': 33, 'clave2': 3, 'clave3': 24}

# %% [markdown]
# Necesito guardar la información de cuántas veces se repite cada nombre:
#
# Diego, Tania, Katherine, Juan, Alex, Alejandro, Diego, Juan, Alex, Diego, Tania, Katherine, Juan, Juan, Alex, Alejandro, Alex, Tania, Katherine, Alejandro

# %%
# code here

# %% [markdown]
# Actualizar con la siguiente información:
#
# Tania, Paul, Juan, Paul

# %%
# code here

# %% [markdown]
# Automatizar el proceso

# %%
informacion = dict()
# Out:
# {'Diego': 3, 'Tania': 3, 'Katherine': 3, 'Juan': 4, 'Alex': 4, 'Alejandro': 3}

# %% [markdown]
# Métodos

# %%
dir(informacion)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
informacion
# Out:
# {'Alejandro': 3,
#  'Alex': 4,
#  'Diego': 3,
#  'Juan': 5,
#  'Katherine': 3,
#  'Paul': 2,
#  'Tania': 4}

# %%
# Get un valor por defecto si la key no está en el diccionario
informacion.get('Pedrito', 0)
# Out:
# 0

# %%
informacion = dict()

nombres = ['Diego','Tania','Katherine','Juan','Alex','Alejandro','Diego','Juan','Alex','Diego','Tania','Katherine','Juan','Juan','Alex','Alejandro','Alex','Tania','Katherine','Alejandro']

for nombre in nombres:
  informacion[nombre] = informacion.get(nombre, 0) + 1
print(informacion)
# Out:
# {'Diego': 3, 'Tania': 3, 'Katherine': 3, 'Juan': 4, 'Alex': 4, 'Alejandro': 3}

# %% [markdown]
# TAREA
#
# Ingrese por pantalla un texto (largo), se busca contar las veces que aparece cada palabra en el texto. Almacenar esto en un diccionario

# %%
#code here

# %%
print('Comenta si te ha gustado la charla y qué quisieras aprender: ')
comentario = input()
# Out:
# Comenta si te ha gustado la charla y qué quisieras aprender:
# Es una buena alternativa para optar por este lenguaje en el mundo de la programación, puesto que es un lenguaje muy sencillo y fácil. Su sintaxis es fácil de entender puesto que es cercana al lenguaje natural, y los programas hechos en Python parecen pseudocódigos

# %% [markdown]
# Keys and Values

# %%
informacion.keys()
# Out:
# dict_keys(['Diego', 'Tania', 'Katherine', 'Juan', 'Alex', 'Alejandro'])

# %%
informacion.values()
# Out:
# dict_values([3, 3, 3, 4, 4, 3])

# %%
informacion.items() # Resultado: tupla
# Out:
# dict_items([('Diego', 3), ('Tania', 3), ('Katherine', 3), ('Juan', 4), ('Alex', 4), ('Alejandro', 3)])

# %% [markdown]
# ## Loops con diccionarios

# %%
for clave in informacion:
  print(clave, informacion[clave])
# Out:
# Diego 3
# Tania 3
# Katherine 3
# Juan 4
# Alex 4
# Alejandro 3

# %%
for clave, valor in informacion.items():
  print(clave, valor)
# Out:
# Diego 3
# Tania 3
# Katherine 3
# Juan 4
# Alex 4
# Alejandro 3

# %% [markdown]
# # Tuplas
# Son otro tipo de secuencia, se parecen un poco a las listas PERO son objetos **inmutables**

# %%
tupla1 = ('Kathy', 'Juan', 'Pedro')
type(tupla1)
# Out:
# tuple

# %%
print(tupla1[1])
# Out:
# Juan

# %%
tupla1[1] = 'Pablo'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-33f007e5ad2c> in <module>()
# ----> 1 tupla1[1] = 'Pablo'
#
# TypeError: 'tuple' object does not support item assignment

# %%
(x, y) = (2, 55)
print(y)
print(x)
# Out:
# 55
# 2

# %% [markdown]
# Tuplas y diccionarios

# %%
x = informacion.items()

# %%
x # list of tuples
# Out:
# dict_items([('Diego', 3), ('Tania', 3), ('Katherine', 3), ('Juan', 4), ('Alex', 4), ('Alejandro', 3)])
