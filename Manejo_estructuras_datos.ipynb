# %% [markdown]
# <center> <h1> Estructuras de datos en Python </h1>
#
# ![image](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTncB2fp8FCRjubfKXk8Hvl_NA8ycwu2BmHwQ&usqp=CAU)
#
# </center>
#
#
#
#
# Expositor: Katherine Morales
#
# - Linkedin [in/katherine-morales-7194a3108/](https://www.linkedin.com/in/katherine-morales-7194a3108/)

# %% [markdown]
# # String Data Type
#
# - Es una secuencia de caracteres
# - Para strings, + significa concatenar
# - Cuando un string cintiene números, este es todavía un string
# - Podemos convertir números que están en formato string a un número utilizando **int()**

# %%
str1 = "Hola"
str2 = ' mundo'
# comillas simples y comillas dobles no importa!

# %%
msj = str1 + str2
print(msj)
# Out:
# Hola mundo

# %%
str3 = '123'
x = str3 + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-2c2d46e20be7> in <module>()
#       1 str3 = '123'
# ----> 2 x = str3 + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
x = int(str3) + 1
print(x)
# Out:
# 124

# %% [markdown]
# ## Leer y transformar
#
# Cuando 'leemos' los datos puede suceder que se lean como strings (es lo que prefiere la máquina.

# %%
entrada = input('Ingrese un nombre ')
# Out:
# Ingrese un nombre Katherine

# %%
entrada
# Out:
# 'Katherine'

# %%
print(type(entrada))
entrada.__class__
# Out:
# <class 'str'>
# str

# %%
edad = input('Ingrese su edad: ')
# Out:
# Ingrese su edad: 27

# %%
edad
# Out:
# '27'

# %%
edad + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-aef667aea955> in <module>()
# ----> 1 edad + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Solución al problema
# Aqui

# %% [markdown]
# ## Buscando dentro de los strings
#
# - Utilizamos corchetes para acceder a un caracter  []
# - El índice debe ser entero
# - También puede ser una expresión calculable

# %%
nombre = 'Tatiana'
# 0  1  2 3 4 5 6  
# T  a  t i a n a

# %%
letra = nombre[5]

# %%
print(letra)
# Out:
# n

# %%
indice =  2
letra2 = nombre[indice*2]

# %%
letra2
# Out:
# 'a'

# %%
seq = nombre[0:4]
seq
# 4 no est'a incluido
# Out:
# 'Tati'

# %% [markdown]
# - Len function

# %%
ejemplo = 'taller'
len(ejemplo)
# Out:
# 6

# %%
ejemplo2 = 'taller python'
len(ejemplo2)
# Out:
# 13

# %% [markdown]
# - Loops con strings
#
# Tarea:
# Usando **while** y una variable de iteración, con ayuda de len, se imprima en pantalla el índice y la letra correspondiente
#
# 0 t
#
# 1 a
#
# 2 l
#
# 3 l
#
# 4 e
#
# 5 r
#
#
#
# - La variiable de iteración itera a lo largo de la seguencia
# - Ejecuta el cuerpo, el bloque de código
# - La variable de iteración se mueve a lo largo de todos los valores en la secuencia

# %%
indice = 0


while indice < len(ejemplo):
  print(indice, ejemplo[indice] )
  indice += 1 # indice = indice +1
# Out:
# 0 t
# 1 a
# 2 l
# 3 l
# 4 e
# 5 r

# %%
for letra in ejemplo:
  print(letra)
# Out:
# t
# a
# l
# l
# e
# r

# %%
for i, letra in enumerate(ejemplo):
  print(i, letra)
# Out:
# 0 t
# 1 a
# 2 l
# 3 l
# 4 e
# 5 r

# %% [markdown]
# Tarea: contar el número de veces que una letra aparece en una frase

# %%
texto = 'Estamos aprendiendo las estructuras de datos que existen en python y como manejarlas '
# Code here

contador = 0

for letra in texto:
  if letra == 'o':
    contador +=1 # contador = contador + 1

print(contador)

# == comparacion  (T F)
# = asignaci'on

# %% [markdown]
# ## Algunos métodos

# %%
ejemplo3 = 'Katherine Morales'

# %%
ejemplo3.lower()
# Out:
# 'katherine morales'

# %%
ejemplo3.upper()
# Out:
# 'KATHERINE MORALES'

# %%
type(ejemplo3)
# Out:
# str

# %%
dir(ejemplo3)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
ejemplo3.split()
# Out:
# ['Katherine', 'Morales']

# %%
ejemplo3.replace('Katherine', 'Tania')
# Out:
# 'Tania Morales'

# %%
ejemplo3.replace('s', 'z')
# Out:
# 'Katherine Moralez'

# %%
ejemplo3
# Out:
# 'Katherine Morales'

# %%
# find
# lstrip
# rstirp
# strip

# %%
# análisis sintáctico y extracción

# %% [markdown]
# ## Extras

# %%
ejemplo
# Out:
# 'taller'

# %%
'e' in ejemplo
# Out:
# True

# %%
'k' not in ejemplo
# Out:
# True

# %%
ejemplo > ejemplo2
# Out:
# False

# %% [markdown]
# - Análisis sintáctico y extracción
# - Strings y conjuntos de caracteres

# %% [markdown]
# # Listas
#
# Al igual que un string, una lista es una secuencia de valores. En una cadena, los valores son caracteres; en una lista, pueden ser de cualquier tipo. Los valores de una lista se denominan elementos o, a veces, ítems.

# %%
lista1 = [1, 2, 3, 5]

# %%
lista2 = ['Curso', 'Python', 'Estructuras', 'Datos']

# %%
lista3 = [1, [3,5], 3]

# %%
lista = []

# %%
for k in lista1:
  print(k)
# Out:
# 1
# 2
# 3
# 5

# %% [markdown]
# Tarea: Crear una lista de  5 nombres e imprimer el mensaje personalizado para cada uno de ellos de Feliz Navidad (Nombre)
#
# Feliz Navidad Pablo!
#
# Feliz Navidad Mariana!

# %%
# Code here
nombres = []

# %% [markdown]
# - Listas son mutables (podemos cambiar un elemento de una lista usando el operador index)
#
# - Strings son inmutables (no podemos cambiar el contenido de un string)

# %%
ejemplo3
ejemplo3[5] =  's'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-1dd71583fc87> in <module>()
#       1 ejemplo3
# ----> 2 ejemplo3[5] =  's'
#
# TypeError: 'str' object does not support item assignment

# %%
print(lista1)
lista1[2] = 35
print(lista1)
# Out:
# [1, 2, 3, 5]
# [1, 2, 35, 5]

# %% [markdown]
# El tamaño de una lista - len()

# %%
len(lista1)
# Out:
# 4

# %% [markdown]
# Acceder a los elementos []

# %%
lista1
# Out:
# [1, 2, 3, 5]

# %%
lista1[0:3]
# Out:
# [1, 2, 35]

# %%
type(lista1)
# Out:
# list

# %% [markdown]
# ### Métodos de una lista

# %%
dir(lista1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
lista1
# Out:
# [1, 2, 3, 5]

# %%
x = []

x = list()
x
# Out:
# []

# %%
x.append(4)
x
# Out:
# [4]

# %%
x.append(5)

# %%
x
# Out:
# [4, 5]

# %%
x.remove(4)

# %%
x
# Out:
# [5]

# %% [markdown]
# - Enlace strings con listas

# %%
texto = 'Estamos aprendiendo las estructuras de datos que existen en python y como manejarlas'
texto
# Out:
# 'Estamos aprendiendo las estructuras de datos que existen en python y como manejarlas'

# %%
palabras = texto.split()
palabras
# Out:
# ['Estamos',
#  'aprendiendo',
#  'las',
#  'estructuras',
#  'de',
#  'datos',
#  'que',
#  'existen',
#  'en',
#  'python',
#  'y',
#  'como',
#  'manejarlas']

# %%
texto2 = 'Este es un ejemplo. Para separar. por puntos'
texto2.split('.')
# Out:
# ['Este es un ejemplo', ' Para separar', ' por puntos']

# %%
texto3 = 'micorreo@dominio'
texto3.split('@')
# Out:
# ['micorreo', 'dominio']

# %%
lista1 + lista2
# Out:
# [1, 2, 35, 5, 'Curso', 'Python', 'Estructuras', 'Datos']

# %%
lista2*3
# Out:
# ['Curso',
#  'Python',
#  'Estructuras',
#  'Datos',
#  'Curso',
#  'Python',
#  'Estructuras',
#  'Datos',
#  'Curso',
#  'Python',
#  'Estructuras',
#  'Datos']

# %% [markdown]
# # Dictionaries
#
# - Key
# - Value
#
# -

# %%
d1 = dict()


d1['clave1'] = 5000
d1['clave2'] = 3000
d1['clave3'] = 2440
d1
# Out:
# {'clave1': 5000, 'clave2': 3000, 'clave3': 2440}

# %%
d1['clave1']
# Out:
# 5000

# %%
d1['clave1'] = 33
d1
# Out:
# {'clave1': 33, 'clave2': 3000, 'clave3': 2440}

# %% [markdown]
# Necesito guardar la información de cuántas veces se repite cada nombre:
#
# Diego, Tania, Katherine, Juan, Alex, Alejandro, Diego, Juan, Alex, Diego, Tania, Katherine, Juan, Juan, Alex, Alejandro, Alex, Tania, Katherine, Alejandro

# %%
# code here
informacion = dict()

nombres = ['Diego','Tania','Katherine','Juan','Alex','Alejandro','Diego','Juan','Alex','Diego','Tania','Katherine','Juan','Juan','Alex','Alejandro','Alex','Tania','Katherine','Alejandro']

for nombre in nombres:
  if nombre not in informacion:
    informacion[nombre] = 1
  else:
    informacion[nombre] += 1 

print(informacion)
# Out:
# {'Diego': 3, 'Tania': 3, 'Katherine': 3, 'Juan': 4, 'Alex': 4, 'Alejandro': 3}

# %% [markdown]
# Actualizar con la siguiente información:
#
# Tania, Paul, Juan, Paul

# %%
# code here

nombres = ['Tania','Paul','Juan','Paul']

for nombre in nombres:
  if nombre not in informacion:
    informacion[nombre] = 1
  else:
    informacion[nombre] += 1

print(informacion)
# Out:
# {'Diego': 3, 'Tania': 4, 'Katherine': 3, 'Juan': 5, 'Alex': 4, 'Alejandro': 3, 'Paul': 2}

# %% [markdown]
# Automatizar el proceso

# %%
informacion = dict()
# Out:
# {'Diego': 3, 'Tania': 3, 'Katherine': 3, 'Juan': 4, 'Alex': 4, 'Alejandro': 3}

# %% [markdown]
# Métodos

# %%
dir(informacion)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
informacion
# Out:
# {'Alejandro': 3,
#  'Alex': 4,
#  'Diego': 3,
#  'Juan': 5,
#  'Katherine': 3,
#  'Paul': 2,
#  'Tania': 4}

# %%
# Get un valor por defecto si la key no está en el diccionario
informacion.get('Pedrito', 0)
# Out:
# 0

# %%
informacion = dict()

nombres = ['Diego','Tania','Katherine','Juan','Alex','Alejandro','Diego','Juan','Alex','Diego','Tania','Katherine','Juan','Juan','Alex','Alejandro','Alex','Tania','Katherine','Alejandro']

for nombre in nombres:
  informacion[nombre] = informacion.get(nombre, 0) + 1
print(informacion)
# Out:
# {'Diego': 3, 'Tania': 3, 'Katherine': 3, 'Juan': 4, 'Alex': 4, 'Alejandro': 3}

# %% [markdown]
# TAREA
#
# Ingrese por pantalla un texto (largo), se busca contar las veces que aparece cada palabra en el texto. Almacenar esto en un diccionario

# %%
#code here

# %%
print('Comenta si te ha gustado la charla y qué quisieras aprender: ')
comentario = input()
# Out:
# Comenta si te ha gustado la charla y qué quisieras aprender:
# Son otro tipo de secuencia, se parecen un poco a las listas PERO son objetos  inmutables

# %%
palabras = comentario.split()
palabras
# Out:
# ['Son',
#  'otro',
#  'tipo',
#  'de',
#  'secuencia,',
#  'se',
#  'parecen',
#  'un',
#  'poco',
#  'a',
#  'las',
#  'listas',
#  'PERO',
#  'son',
#  'objetos',
#  'inmutables']

# %%
informacion2 = dict()
for palabra in palabras:
  informacion2[palabra] = informacion2.get(palabra, 0) + 1
print(informacion2)
# Out:
# {'Son': 1, 'otro': 1, 'tipo': 1, 'de': 1, 'secuencia,': 1, 'se': 1, 'parecen': 1, 'un': 1, 'poco': 1, 'a': 1, 'las': 1, 'listas': 1, 'PERO': 1, 'son': 1, 'objetos': 1, 'inmutables': 1}

# %% [markdown]
# Keys and Values

# %%
informacion.keys()
# Out:
# dict_keys(['Diego', 'Tania', 'Katherine', 'Juan', 'Alex', 'Alejandro'])

# %%
informacion.values()
# Out:
# dict_values([3, 3, 3, 4, 4, 3])

# %%
informacion.items() # Resultado: tupla
# Out:
# dict_items([('Diego', 3), ('Tania', 3), ('Katherine', 3), ('Juan', 4), ('Alex', 4), ('Alejandro', 3)])

# %% [markdown]
# ## Loops con diccionarios

# %%
for clave in informacion:
  print(clave, informacion[clave])
# Out:
# Diego 3
# Tania 3
# Katherine 3
# Juan 4
# Alex 4
# Alejandro 3

# %%
for clave, valor in informacion.items():
  print(clave, valor)
# Out:
# Diego 3
# Tania 3
# Katherine 3
# Juan 4
# Alex 4
# Alejandro 3

# %% [markdown]
# # Tuplas
# Son otro tipo de secuencia, se parecen un poco a las listas PERO son objetos **inmutables**

# %%
tupla1 = ('Kathy', 'Juan', 'Pedro')
type(tupla1)
# Out:
# tuple

# %%
print(tupla1[1])
# Out:
# Juan

# %%
tupla1[1] = 'Pablo'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-33f007e5ad2c> in <module>()
# ----> 1 tupla1[1] = 'Pablo'
#
# TypeError: 'tuple' object does not support item assignment

# %%
(x, y) = (2, 55)
print(y)
print(x)
# Out:
# 55
# 2

# %% [markdown]
# Tuplas y diccionarios

# %%
x = informacion.items()

# %%
x # list of tuples
# Out:
# dict_items([('Diego', 3), ('Tania', 3), ('Katherine', 3), ('Juan', 4), ('Alex', 4), ('Alejandro', 3)])
